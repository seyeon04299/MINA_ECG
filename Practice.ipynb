# %%
import torch

# %%
PATH = '/ubuntu/SY/classification-MINA/result/20210404/model/MINANet_title_210404-050718.pth'

# %%
checkpoint = torch.load(PATH)

# %%
checkpoint.keys()
# Out:
# dict_keys(['inplanes', 'kernel_size', 'num_blocks', 'model_output', 'loss_lambda', 'num_layers', 'diminution', 'hidden_size', 'dropout', 'num_epochs', 'oversample_ratio', 'data_path', 'ext_path', 'lead_type', 'mode', 'num_workers', 'gpus', 'num_classes', 'comment', 'lr', 'batch_size', 'gamma', 'alpha', 'calibration', 'pre_trained', 'num_gpus', 'intv_data', 'extv_data', 'input_shape', 'weight', 'temp', 'optim'])

# %%
setattr(checkpoint,'mode',"test")

# %%
checkpoint
# Out:
# {'inplanes': 64,
#  'kernel_size': 32,
#  'num_blocks': None,
#  'model_output': 2,
#  'loss_lambda': 0.7,
#  'num_layers': None,
#  'diminution': None,
#  'hidden_size': 64,
#  'dropout': 0.5,
#  'num_epochs': 50,
#  'oversample_ratio': 0.0,
#  'data_path': '../physionet_subject_map.csv',
#  'ext_path': None,
#  'lead_type': 'original',
#  'mode': 'test',
#  'num_workers': 10,
#  'gpus': [0, 1],
#  'num_classes': 2,
#  'comment': 'title_210404-050718',
#  'lr': 0.0001,
#  'batch_size': 128,
#  'gamma': 2.0,
#  'alpha': 0.5,
#  'calibration': 1,
#  'pre_trained': None,
#  'num_gpus': 2,
#  'intv_data': <config.SplitData at 0x7f971046f470>,
#  'extv_data': None,
#  'input_shape': torch.Size([4, 8081]),
#  'weight': OrderedDict([('W_att_channel', tensor([[-0.2400, -0.3479],
#                        [-0.2568, -2.1817],
#                        [-0.2451,  0.7264],
#                        [ 0.0337, -0.2294],
#                        [-0.9311,  1.5223],
# ...

# %%
checkpoint.intv_data

# %%
a = []

# %%
a = a + ['a']

# %%
a
# Out:
# ['a']

# %%
(1621-1)*2*40/(2*40+1)
# Out:
# 1600.0

# %%
(40*(1621-1))/(81)
# Out:
# 800.0

# %%
for i in range(10):
    print(4*i,4*(i+1))
# Out:
# 0 4
# 4 8
# 8 12
# 12 16
# 16 20
# 20 24
# 24 28
# 28 32
# 32 36
# 36 40

# %%
# !pwd
import pandas as pd
# Out:
# /ubuntu/SY/classification-MINA

# %%
df = pd.read_csv('/ubuntu/SY/PTBXL_subjectmap_N_MI.csv', dtype={'fname' : 'str'}, index_col=0).reset_index(drop=False)

# %%
'ptb-xl' in df['site'].unique()
# Out:
# True

# %%
import torch.nn.functional as F 
import numpy as np

# %%
a = np.array([[0.7,0.3],[0.6,0.4]])

# %%
b = torch.tensor(a)

# %%
F.softmax(b,dim=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   """Entry point for launching an IPython kernel.
# tensor([[0.5987, 0.4013],
#         [0.5498, 0.4502]], dtype=torch.float64)
